# %% [markdown]
# <a href="https://colab.research.google.com/github/samratchakraborty422000/Python-basics-Assignments/blob/main/programming_assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python Program to find sum of array?

# %%
print("Enter the array")
arr=list(map(float,input().split()))
print(f"sum of the array {sum(arr)}")
# Out:
# Enter the array
# 4 5 6 7
# sum of the array 22.0

# %% [markdown]
# 2. Write a Python Program to find largest element in an array?

# %%
print("Enter the array")
arr=list(map(float,input().split()))
print(f"Lartgest element of the array {max(arr)}")
# Out:
# Enter the array
# 12 45 67 89
# Lartgest element of the array 89.0

# %% [markdown]
# 3. Write a Python Program for array rotation?

# %%
def rotateArray(arr,d):
    temp = []
    n=len(arr)
    for i in range(d,n):
        temp.append(arr[i])
    i = 0
    for i in range (0,d):
        temp.append(arr[i])
    arr=temp.copy()
    return arr

arr=list(input().split())
r=int(input("rotate by:"))
print("Array after left rotation is: ", end=' ')
print(rotateArray(arr,r))
# Out:
# 1 2 3 4 5 6 7 8 9 0
# rotate by:4
# Array after left rotation is:  ['5', '6', '7', '8', '9', '0', '1', '2', '3', '4']

# %% [markdown]
# 4. Write a Python Program to Split the array and add the first part to the end?

# %%
def split(arr,d):
    n=len(arr)
    arr[:]=arr[d:n]+arr[0:d]
    return arr
arr=list(input().split())
r=int(input("split by no. of elements:"))
print("After splitting")
print(split(arr,r))
# Out:
# 1 23 4 5 6 7 8 9 0
# split by no. of elements:4
# After splitting
# ['6', '7', '8', '9', '0', '1', '23', '4', '5']

# %% [markdown]
# 5. Write a Python Program to check if given array is Monotonic?

# %%
def isMonotonic(arr):
    return (all(arr[i]<=arr[i+1] for i in range(len(arr)-1)) or
            all(arr[i]>=arr[i+1] for i in range(len(arr)-1)))
arr=list(map(float,input().split()))
print(isMonotonic(arr))
# Out:
# 1 2 3 4 5 6 7 8 9 0
# False
