# %% [markdown]
# <a href="https://colab.research.google.com/github/samratchakraborty422000/Python-basics-Assignments/blob/main/programming_assignment_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python program to find words which are greater than given length k?

# %%
l=[]
n=int(input("enter the number of elements in the list:"))
for i in range(n):
  l.append(input())
k=int(input("enter the value of k:"))
for i in l:
  if type(i)==str and len(i)>k:
    print(i)
# Out:
# enter the number of elements in the list:5
# a
# aa
# aaa
# aaaa
# aaaaa
# enter the value of k:3
# aaaa
# aaaaa

# %% [markdown]
# 2. Write a Python program for removing i-th character from a string?

# %%
str1=input("enter the string: ")
i=int(input("enter the value of i : "))
str2=str1[0:i]+str1[i+1:]
print(str2)
# Out:
# enter the string: samrat chakraborty
# enter the value of i : 5
# samra chakraborty

# %% [markdown]
# 3. Write a Python program to split and join a string?

# %%
str1=input("enter the string: ")
print(str1.split(" "))  #splitting
print("/".join(str1.split()))  #joining
# Out:
# enter the string: today is 21 02 2023
# ['today', 'is', '21', '02', '2023']
# today/is/21/02/2023

# %% [markdown]
# 4. Write a Python to check if a given string is binary string or not?

# %%
string=input("enter the string: ")
p = set(string)
s = {'0', '1'}
if s == p or p == {'0'} or p == {'1'}:
    print("It is a binary string")
else:
  print("It is not a binary string.")
# Out:
# enter the string: 10192827393
# It is not a binary string.

# %% [markdown]
# 5. Write a Python program to find uncommon words from two Strings?

# %%
def uncommon_words(A, B):
    A=A.split()
    B=B.split()
    x=[]
    for i in A:
        if i not in B:
            x.append(i)
    for i in B:
        if i not in A:
            x.append(i)
    x=list(set(x))
    return x
A=input()
B=input()
print(uncommon_words(A, B))
# Out:
# i am a good boy
# i am a college student
# ['college', 'student', 'boy', 'good']

# %% [markdown]
# 6. Write a Python to find all duplicate characters in string?

# %%
def duplicate_characters(A, B):
    x=[]
    for i in A:
        if i in B:
            x.append(i)
    for i in B:
        if i in A:
            x.append(i)
    x=list(set(x))
    return x
A=input()
B=input()
print(duplicate_characters(A, B))
# Out:
# abcdefghijkl
# defghirty
# ['h', 'e', 'f', 'i', 'g', 'd']

# %% [markdown]
# 7. Write a Python Program to check if a string contains any special character?

# %%
special = '''!@#$%^&*()_+-={}:"|<>?/.,\';][*-+]'''
a=input("Enter a string: ")
char=False
for i in a:
   if i in special:
     char=True
if char==True:
  print("yes")
else:
  print("No")
# Out:
# Enter a string: it will print YES!
# yes
