# %% [markdown]
# <a href="https://colab.research.google.com/github/samratchakraborty422000/Python-basics-Assignments/blob/main/programming_assignment_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question1. Write a function that stutters a word as if someone is struggling to read it. The
# first two letters are repeated twice with an ellipsis ... and space after each, and then the
# word is pronounced with a question mark ?.

# %%
def shutter(n):
    a=n[:2]
    print(f'{a}...{a}...'+n)
n= input()
shutter(n)
# Out:
# definition
# de...de...definition

# %% [markdown]
# Question 2.Create a function that takes an angle in radians and returns the corresponding
# angle in degrees rounded to one decimal place.

# %%
def radians_to_degrees(x):
    from math import pi 
    radian = float(input("Input radians: "))
    degree = radian*(180/pi)
    print(round(degree,1))
radians_to_degrees(n)
# Out:
# Input radians: 1
# 57.3

# %% [markdown]
# Question 3. In this challenge, establish if a given integer num is a Curzon number. If 1 plus
# 2 elevated to num is exactly divisible by 1 plus 2 multiplied by num, then num is a Curzon
# number.
# Given a non-negative integer num, implement a function that returns True if num is a Curzon
# number, or False otherwise.

# %%
def is_curzon():
    n=int(input())
    a=2**n+1
    b=2*n+1
    if a%b==0:
        return True
    else: return False
is_curzon()
# Out:
# 5
# True

# %% [markdown]
# Question 4.Given the side length x find the area of a hexagon.

# %%
from math import sqrt
def area():
    import math
    s=int(input("enter the side:"))
    a=3*sqrt(3)*(s**2)/2
    print(round(a,1))
area()
# Out:
# enter the side:1
# 2.6

# %% [markdown]
# Question 5. Create a function that returns a base-2 (binary) representation of a base-10
# (decimal) string number. To convert is simple: ((2) means base-2 and (10) means base-10)
# 010101001(2) = 1 + 8 + 32 + 128.
# Going from right to left, the value of the most right bit is 1, now from that every bit to the left
# will be x2 the value, value of an 8 bit binary numbers are (256, 128, 64, 32, 16, 8, 4, 2, 1).

# %%
def binary(n):
    if n >= 1:
       binary(n // 2)
    print(n%2, end = '')
n=int(input())
binary(n)
# Out:
# 10
# 01010
