# %% [markdown]
# <a href="https://colab.research.google.com/github/samratchakraborty422000/Python-basics-Assignments/blob/main/programming_assignment_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a function that takes three arguments a, b, c and returns the sum of the
# numbers that are evenly divided by c from the range a, b inclusive.

# %%
def evenly_divisible(a,b,c):
    sum=0
    for i in range(a,b+1):
        if i%2==0:
            sum+=i
    return sum
a,b,c=map(int,input().split())
evenly_divisible(a,b,c)
# Out:
# 1 10 2
# 30

# %% [markdown]
# Create a function that replaces all the vowels in a string with a specified character.

# %%
def replace_vowel(str1,char):
    newstr = ""
    vowels = ['a', 'e', 'i', 'o', 'u', 'A', 'E', 'I', 'O', 'U']

    for i in range(len(str1)):
        if str1[i] in vowels:
            newstr = newstr + char
        else:
            newstr = newstr + str1[i]

    print("\nOriginal String =", str1)
    print("New String =", newstr)
s=input("enter the string:")
a=input("enter the specified character:")
replace_vowel(s,a)
# Out:
# enter the string:aaaaabbbbb
# enter the specified character:#
#
# Original String = aaaaabbbbb
# New String = #####bbbbb

# %% [markdown]
# Write a function that calculates the factorial of a number recursively.

# %%
def fact(n):
    if n<0:
        print("Factorial only exist for non negative whole numbers.")
    if n==0:
        return 1
    if n == 1:
        return n
    else:
        return n*fact(n-1)
n=int(input())
fact(n)
# Out:
# 5
# 120

# %% [markdown]
# Hamming distance is the number of characters that differ between two strings.
# To illustrate:
# String1: &quot;abcbba&quot;
# String2: &quot;abcbda&quot;
# Hamming Distance: 1 - &quot;b&quot; vs. &quot;d&quot; is the only difference.
# Create a function that computes the hamming distance between two strings.

# %%
def hamming_distance(string1, string2): 
    distance = 0
    for i in range(len(string1)):
        if string1[i] != string2[i]:
            distance += 1
    return distance
string1=input()
string2=input()
hamming_distance(string1,string2)
# Out:
# abcde
# abcef
# 2
